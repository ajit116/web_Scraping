# %%
#dependencies
from bs4 import BeautifulSoup
from urllib.request import urlopen
import csv

# %%
urlpage =  'http://www.fasttrack.co.uk/league-tables/tech-track-100/league-table/'

# %%
souce = urlopen(urlpage)

# %%
soup = BeautifulSoup(souce, 'html.parser')

# %%
souce

# %%
soup
# Out:
# <!-- Template Name: League Table page
# -->
# <!DOCTYPE html>
#
# <!--[if lt IE 7 ]> <html class="ie ie6 no-js" lang="en-GB" prefix="og: http://ogp.me/ns#"> <![endif]-->
# <!--[if IE 7 ]>    <html class="ie ie7 no-js" lang="en-GB" prefix="og: http://ogp.me/ns#"> <![endif]-->
# <!--[if IE 8 ]>    <html class="ie ie8 no-js" lang="en-GB" prefix="og: http://ogp.me/ns#"> <![endif]-->
# <!--[if IE 9 ]>    <html class="ie ie9 no-js" lang="en-GB" prefix="og: http://ogp.me/ns#"> <![endif]-->
# <!--[if gt IE 9]><!--><html class="no-js" lang="en-GB" prefix="og: http://ogp.me/ns#"><!--<![endif]-->
# <!-- the "no-js" class is for Modernizr. -->
# <head id="live2-fasttrack-com">
# <meta charset="utf-8"/>
# <!-- Always force latest IE rendering engine (even in intranet) & Chrome Frame -->
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <title>
# 		League table - Fast Track	</title>
# <meta content="League table - Fast Track" name="title"/>
# ...

# %%
print(soup.title.text)
# Out:
# 		League table - Fast Track

# %% [markdown]
# *  All the *url link* connected to the main page are:

# %%
for url in soup.find_all('a'):
    print(url.text)
# Out:
# Tech Track 100
# FAST TRACK
# We are hiring
# Home
# News
# SME Export Track 100
# Overview
# League table
# Supplement & research
# Awards dinner
# Nominate a company
# Sponsorship
# Tech Track 100
# Overview
# League table
# Supplement & research
# Awards dinner
# Ones to Watch
# Alumni dinners
# Nominate a company
# Sponsorship
# Fast Track 100
# Overview
# League table
# Supplement & research
# Awards dinner
# Disruptors/Ones to Watch
# Alumni dinners
# Nominate a company
# Sponsorship
# International Track 200
# Overview
# League table
# Supplement & research
# Awards dinner
# Alumni dinners
# Nominate a company
# Sponsorship
# Profit Track 100
# Overview
# League table
# Supplement & research
# Awards dinner
# Ones to Watch
# Alumni dinners
# Nominate a company
# Sponsorship
# Top Track 250
# Overview
# League table
# Supplement & research
# Awards dinner
# Ones to Watch
# Alumni dinners
# Nominate a company
# Sponsorship
# Top Track 100
# Overview
# League table
# ...

# %%
import pandas as pd
dfs = pd.read_html(urlpage, header = 0)
for df in dfs:
    print(df)
# Out:
#     Rank                                            Company         Location  \
# 0      1                    Plan.comCommunications provider      Isle of Man
# 1      2                     PsiOxusBiotechnology developer      Oxfordshire
# 2      3         CensorNetCloud security software developer      Basingstoke
# 3      4          thoughtonomyAutomation software developer      East London
# 4      5                PerkboxEmployee engagement services   Central London
# 5      6                         OguryMobile data marketing     North London
# 6      7                  VerveMarketing software developer   Central London
# 7      8          goHenryChildren's pre-paid card developer   Central London
# 8      9                   DarktraceCybersecurity developer        Cambridge
# 9     10                      BizumaB2B e-commerce platform   Central London
# 10    11                           DepopSocial shopping app   Central London
# ...

# %% [markdown]
# * length of the table

# %%
table = soup.find('table', attrs={'class': 'tableSorter'})
results = table.find_all('tr')
print('Number of results', len(results))
# Out:
# Number of results 101

# %% [markdown]
# Saving the data into file

# %%
dfs[0].to_csv('C://Users//DELL//Desktop//Data Science//BeautifulSoup_3.csv', header=True)
